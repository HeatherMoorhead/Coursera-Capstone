# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 5 -Report)

# %% [markdown]
# ## Introduction

# %% [markdown]
# **Background:**
# New York City (NYC) is located on the east coast of American in New York state. The city is made up of five boroughs: Manhattan, Brooklyn, Queens, the Bronx and Staten Island. These boroughs are further separated into 306 neighborhoods. NYC is a multicultural hub of businesses and restaurants and is home to over 8 million people that speak over 800 languages. Additionally, NYC is known for its diverse food culture and is esimated to have over 23,650 restaurants and bars.
#
# **Business problem:**
# Restaurant owner Mr Ricci owns one very successful Italian restaurant in the Upper West Side of Manhattan, NYC. He very recently secured capital from several investors who want to help Mr Ricci franchise his restaurant and open up more stores in different boroughs/ neighborhoods of NYC. Mr Ricci is willing to open more restaurants in either Brooklyn or Manhattan. The problem is that Mr Ricci does not know which neighborhoods within the two boroughs are best to open up his next franchise.
#
# **Stakeholders:**
# The stakehodelers in this project include Mr Ricci, his family who help manage the restaurant, his employees (who may move to work at future franchises) as well as his investors who want to see a good return on investment.

# %% [markdown]
# ## Data Description

# %% [markdown]
# To help Mr Ricci solve his problem and identify suitable neighbourhoods to open his next franchise I will use two sources of data. The first source of data is a JSON file provided by Coursera containing the name of each of 306 neighborhoods and their respective boroughs as well as latitude and longitude coordinates for each neighborhood. The second source of data will be obtained using the Foursquare API.
#
# I will use the Foursquare API to retrive location information on all of the neighborhoods in Manhattan and Brooklyn. The API will give us information of the types of venues and most common venues within a 500m radius of each coordinate. Using the top 10 most common venues in each neighborhhood I will use K-means clustering to find groups of similar neighborhoods. The neighborhoods most similar to the Upper West Side should be suitable areas to open Mr Ricci's next franchise.

# %% [markdown]
# ## Methods

# %% [markdown]
# 1. Clarify the business problem as reported by the client (Mr Ricci).
# 2. Obtain Data about the boroughs and neighborhoods within NYC including latitude and longitude coordinates and import into pandas dataframe.
# 3. Use geopy and folium libraries to map the neighbourhoods and visualise the layout.
# 4. Isolate the required data from Manhattan and Brooklyn boroughs only.
# 5. Use Foursquare to Investigate the Upper West Side where Mr Riccis first restaurant is located.
# 6. Use Foursquare to identify the top 10 most common venues within a 500m radius of all neighborhoods within Manhattan and Brooklyn.
# 7. Run K-means clustering on the data. Experient with different values of k.
# 8. Examine the resulting clusters and identify which cluster contains the Upper West Side.
# 9. The Neighborhoods within this cluster are most similar to the Upper West Side where Mr Riccis restaurant is located. These locations are candidate franchise locations.
#
# All associated code is stored in a separate file entitled "Capstone Project - The Battle of Neighborhoods(Week 5- Code)".

# %% [markdown]
# ## Results

# %% [markdown]
# The Upper West Side belonged to Cluster 1 (the red cluster) which is the largest cluster that the algorithm delivered. This cluster contains:
#
# Chinatown, Manhattanville, Central Harlem, Upper East Side, Yorkville, Lenox Hill, Upper West Side, Lincoln Square, Clinton, Midtown, Murray Hill, Chelsea, Greenwhich Village, East Village, Tribecca, Little Italy, Soho, West Village, Manhattan Valley, Morningside Heights, Gramercy, Financial District, Carnegie Hill, Noho, Civic Centre, Midtown South, Sutton Place, Turtle Bay, Tudor City, Flatiron, Hudson Yards, Bay Ridge, Greenpoint, Windsor Terrace, Prospect Heights, Williamsburg, Bushwick, Bedford Stuyvesant, Brooklyn Heights, Cobble Hill, Carroll Gardens, Red Hook, Gowanus, Fort Greene, Parkslope, Clinton Hill, Sea Gate, Downtown, Boerum Hill, East Williamsburg, North Side, South Side, Vinegar Hill.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Discussion

# %% [markdown]
# It is recommended that Mr Ricci choose location/s from cluster 1 in which to open up his next Italian restaurant franchise as these locations are most similar to the Upper West Side where his original restaurant is located. The similarity in neighborhoods increase the likelihood of success for his franchises.
#
# In order to help Mr Ricci narrow down his location search I decided to recommend locations within cluster 1 that had "Italian restaurant" listed as being in the top 3 most common venues. This left us with 21 locations. These locations are:
#
# Manhattanville, Upper East Side, Yorkville, Lenox Hill, Greenwich Village, Tribeca, Little Italy, Soho, West Village, Gramercy, Noho, Sutton Place, Turtle Bay, Flatiron, Bay Ridge, Brooklyn Heights, Cobble Hill, Carroll Gardens, Gowanus, Fort Greene and Clinton Hill.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This study has provided Mr Ricci with 21 feasible locations to choose from, within Manhattan and Brooklyn, where his new Italian restaurant franchises are most likely to succeed. This will satisfy the needs of all stakeholders involved.
